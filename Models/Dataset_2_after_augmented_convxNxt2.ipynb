# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.22.0 typeguard-2.13.3

# %%
# Import libraries
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import tensorflow as tf
import tensorflow_addons as tfa

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, GlobalMaxPooling2D, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetB0, ResNet101
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# Define dataset2 paths
data_dir = "/content/drive/MyDrive/SHSU-Projects/Final_files/Knee_Dataset_2_Augmented/train_augmented"


# Define batch size
batch_size = 20
IMAGE_SIZE = (240, 240)
classes = ['0Normal', '1Doubtful', '2Mild', '3Moderate', '4Severe']


train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='categorical',
    class_names=classes,  # Specify your class names
    shuffle=True,
    batch_size=batch_size,
    image_size=IMAGE_SIZE,
    validation_split=0.2,  # Adjust the validation split as needed
    subset='training',
    seed=1337
)



val_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='categorical',
    class_names=classes,
    shuffle=True,
    batch_size=batch_size,
    image_size=IMAGE_SIZE,
    validation_split=0.2,
    subset='validation',
    seed=1337
)



class_index_to_label = {i: label for i, label in enumerate(train_dataset.class_names)}
print('Class index number mapping to class folder names: ',class_index_to_label)


def preprocess_image(image, label):
    image = tfa.image.equalize(image)
    return image, label


train_dataset = train_dataset.map(preprocess_image).shuffle(buffer_size=200)
val_dataset = val_dataset.map(preprocess_image)


train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 6725 files belonging to 5 classes.
# Using 5380 files for training.
# Found 6725 files belonging to 5 classes.
# Using 1345 files for validation.
# Class index number mapping to class folder names:  {0: '0Normal', 1: '1Doubtful', 2: '2Mild', 3: '3Moderate', 4: '4Severe'}

# %%
#base_model = tf.keras.applications.efficientnet_v2.EfficientNetV2B0(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
#base_model = tf.keras.applications.resnet.ResNet101(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
base_model = tf.keras.applications.convnext.ConvNeXtBase(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

x = base_model.output
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(612, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(210, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
predictions = tf.keras.layers.Dense(5, activation='softmax')(x)

for layer in base_model.layers:
    layer.trainable = True

model = tf.keras.Model(inputs=base_model.input, outputs=predictions)

# %%
# # Import libraries
# import math
# import sklearn
# import numpy as np
# import tensorflow as tf
# import matplotlib.pyplot as plt

# N_EPOCHS = 20
# warm_up_ep  = 4
# num_cycles  = 0.4
# lr_max = 1e-4

# def learning_rate_fn(current_step, num_warmup_steps, lr_max, num_cycles=0.50, num_training_steps=N_EPOCHS):
#     if current_step < num_warmup_steps:
#         # exponiancial warmup
#         return lr_max * 2 ** -(num_warmup_steps - current_step)
#     else:
#         progress = float(current_step - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))
#         return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr_max


# def plot_lr_schedule(lr_schedule, epochs):
#     fig = plt.figure(figsize=(20, 10))
#     plt.plot([None] + lr_schedule + [None])
#     x = np.arange(1, epochs + 1)
#     x_axis_labels = [i if epochs <= 40 or i % 5 == 0 or i == 1 else None for i in range(1, epochs + 1)]
#     plt.xlim([1, epochs])
#     plt.xticks(x, x_axis_labels) # set tick step to 1 and let x axis start at 1

#     plt.ylim([0, max(lr_schedule) * 1.1])

#     schedule_info = f'start: {lr_schedule[0]:.1E}, max: {max(lr_schedule):.1E}, final: {lr_schedule[-1]:.1E}'
#     plt.title(f'Step Learning Rate Schedule, {schedule_info}', size=18, pad=12)

#     for x, val in enumerate(lr_schedule):
#         if epochs <= 40 or x % 5 == 0 or x is epochs - 1:
#             if x < len(lr_schedule) - 1:
#                 if lr_schedule[x - 1] < val:
#                     ha = 'right'
#                 else:
#                     ha = 'left'
#             elif x == 0:
#                 ha = 'right'
#             else:
#                 ha = 'left'
#             plt.plot(x + 1, val, 'o', color='black');
#             offset_y = (max(lr_schedule) - min(lr_schedule)) * 0.02
#             plt.annotate(f'{val:.1E}', xy=(x + 1, val + offset_y), size=12, ha=ha)

#     plt.xlabel('Epoch', size=16, labelpad=5)
#     plt.ylabel('Learning Rate', size=16, labelpad=5)
#     plt.grid()
#     plt.show()




# LR_SCHEDULE = [learning_rate_fn(step, num_warmup_steps=warm_up_ep, lr_max=lr_max, num_cycles=num_cycles, num_training_steps=N_EPOCHS) for step in range(N_EPOCHS)]
# print('List of learning rate: ', LR_SCHEDULE)

# plot_lr_schedule(LR_SCHEDULE, epochs=N_EPOCHS)
# #lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=0)

# %%
#LR_SCHEDULE

# %%
#lr_list = [ 0.00001, 0.00006, 0.00003, 0.00002, 0.00002, 0.00001, 0.00001, 0.00001, 0.00001, 0.00001, 0.00001 ]


my_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath='/content/drive/MyDrive/SHSU-Projects/Final_files/Dataset_2_after_augmentation_conexnext_2.h5', save_best_only=True),
    #tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),  # Stop training if no improvement after 5 epochs
    #tf.keras.callbacks.LearningRateScheduler(lambda step: lr_list[step], verbose=0),
    #tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=0)
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=3, min_lr=1e-5, verbose=1)
]



model.compile(
    optimizer= tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
        metrics=['accuracy']
)


history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=val_dataset,
    callbacks=[my_callbacks],
)
# Out:
# Epoch 1/20
# 269/269 [==============================] - ETA: 0s - loss: 5.0664 - accuracy: 0.3693
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 163s 368ms/step - loss: 5.0664 - accuracy: 0.3693 - val_loss: 5.9374 - val_accuracy: 0.1985 - lr: 0.0010
# Epoch 2/20
# 269/269 [==============================] - 105s 376ms/step - loss: 1.3005 - accuracy: 0.5314 - val_loss: 5.2087 - val_accuracy: 0.1985 - lr: 0.0010
# Epoch 3/20
# 269/269 [==============================] - 104s 373ms/step - loss: 1.1469 - accuracy: 0.5855 - val_loss: 3.1454 - val_accuracy: 0.3271 - lr: 0.0010
# Epoch 4/20
# 269/269 [==============================] - 101s 363ms/step - loss: 1.0606 - accuracy: 0.6217 - val_loss: 1.6634 - val_accuracy: 0.4364 - lr: 0.0010
# Epoch 5/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.9745 - accuracy: 0.6537 - val_loss: 12.4070 - val_accuracy: 0.1985 - lr: 0.0010
# Epoch 6/20
# 269/269 [==============================] - 103s 367ms/step - loss: 0.9021 - accuracy: 0.6963 - val_loss: 1.2528 - val_accuracy: 0.5428 - lr: 0.0010
# Epoch 7/20
# 269/269 [==============================] - 93s 324ms/step - loss: 0.8101 - accuracy: 0.7377 - val_loss: 1.2890 - val_accuracy: 0.5621 - lr: 0.0010
# Epoch 8/20
# 269/269 [==============================] - 90s 322ms/step - loss: 0.7543 - accuracy: 0.7714 - val_loss: 1.7755 - val_accuracy: 0.4587 - lr: 0.0010
# Epoch 9/20
# 269/269 [==============================] - 91s 322ms/step - loss: 0.6553 - accuracy: 0.8138 - val_loss: 2.2549 - val_accuracy: 0.4431 - lr: 0.0010
# Epoch 10/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.6543 - accuracy: 0.8108 - val_loss: 1.5772 - val_accuracy: 0.5918 - lr: 0.0010
# Epoch 11/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.5509 - accuracy: 0.8578 - val_loss: 1.5619 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 12/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.5232 - accuracy: 0.8725 - val_loss: 2.4904 - val_accuracy: 0.4870 - lr: 0.0010
# Epoch 13/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.4750 - accuracy: 0.8885 - val_loss: 1.4503 - val_accuracy: 0.6498 - lr: 0.0010
# Epoch 14/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.4378 - accuracy: 0.9035 - val_loss: 3.1120 - val_accuracy: 0.4364 - lr: 0.0010
# Epoch 15/20
# 269/269 [==============================] - 90s 322ms/step - loss: 0.4071 - accuracy: 0.9139 - val_loss: 1.5603 - val_accuracy: 0.5978 - lr: 0.0010
# Epoch 16/20
# 269/269 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.9195
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 269/269 [==============================] - 91s 323ms/step - loss: 0.3930 - accuracy: 0.9195 - val_loss: 8.7870 - val_accuracy: 0.3331 - lr: 0.0010
# Epoch 17/20
# 269/269 [==============================] - 105s 375ms/step - loss: 0.2558 - accuracy: 0.9664 - val_loss: 0.8081 - val_accuracy: 0.8104 - lr: 1.0000e-04
# Epoch 18/20
# 269/269 [==============================] - 94s 323ms/step - loss: 0.1953 - accuracy: 0.9844 - val_loss: 0.8923 - val_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 19/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.1676 - accuracy: 0.9894 - val_loss: 0.8218 - val_accuracy: 0.8186 - lr: 1.0000e-04
# Epoch 20/20
# 269/269 [==============================] - 91s 322ms/step - loss: 0.1517 - accuracy: 0.9920 - val_loss: 0.8776 - val_accuracy: 0.8141 - lr: 1.0000e-04

# %%
# Create a dictionary to store layer counts
layer_counts = {}

# Iterate through the model's layers
for layer in model.layers:
    layer_type = type(layer).__name__
    if layer_type in layer_counts:
        layer_counts[layer_type] += 1
    else:
        layer_counts[layer_type] = 1

# Print the total layer counts for each layer type
for layer_type, count in layer_counts.items():
    print(f"Layer type '{layer_type}' is applied {count} times.")
# Out:
# Layer type 'InputLayer' is applied 1 times.
# Layer type 'Normalization' is applied 1 times.
# Layer type 'Sequential' is applied 4 times.
# Layer type 'Conv2D' is applied 36 times.
# Layer type 'LayerNormalization' is applied 37 times.
# Layer type 'Dense' is applied 76 times.
# Layer type 'Activation' is applied 72 times.
# Layer type 'LayerScale' is applied 36 times.
# Layer type 'TFOpLambda' is applied 36 times.
# Layer type 'BatchNormalization' is applied 1 times.
# Layer type 'GlobalAveragePooling2D' is applied 1 times.
# Layer type 'Dropout' is applied 3 times.

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 240, 240, 3)]        0         []
#
#  convnext_base_prestem_norm  (None, 240, 240, 3)          0         ['input_7[0][0]']
#  alization (Normalization)
#
#  convnext_base_stem (Sequen  (None, 60, 60, 128)          6528      ['convnext_base_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          6400      ['convnext_base_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          256       ['convnext_base_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          66048     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          0         ['convnext_base_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          65664     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          128       ['convnext_base_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          0         ['convnext_base_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_36 (T  (None, 60, 60, 128)          0         ['convnext_base_stem[0][0]',
#  FOpLambda)                                                          'convnext_base_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          6400      ['tf.__operators__.add_36[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          256       ['convnext_base_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          66048     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          0         ['convnext_base_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          65664     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          128       ['convnext_base_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          0         ['convnext_base_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_37 (T  (None, 60, 60, 128)          0         ['tf.__operators__.add_36[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          6400      ['tf.__operators__.add_37[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          256       ['convnext_base_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          66048     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          0         ['convnext_base_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          65664     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          128       ['convnext_base_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          0         ['convnext_base_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_38 (T  (None, 60, 60, 128)          0         ['tf.__operators__.add_37[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 30, 30, 256)          131584    ['tf.__operators__.add_38[0][0
#  _block_0 (Sequential)                                              ]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          12800     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          512       ['convnext_base_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         263168    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         0         ['convnext_base_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          262400    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          256       ['convnext_base_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          0         ['convnext_base_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_39 (T  (None, 30, 30, 256)          0         ['convnext_base_downsampling_b
#  FOpLambda)                                                         lock_0[0][0]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          12800     ['tf.__operators__.add_39[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          512       ['convnext_base_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         263168    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         0         ['convnext_base_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          262400    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          256       ['convnext_base_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          0         ['convnext_base_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_40 (T  (None, 30, 30, 256)          0         ['tf.__operators__.add_39[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          12800     ['tf.__operators__.add_40[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          512       ['convnext_base_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         263168    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         0         ['convnext_base_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          262400    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          256       ['convnext_base_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          0         ['convnext_base_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_41 (T  (None, 30, 30, 256)          0         ['tf.__operators__.add_40[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 15, 15, 512)          525312    ['tf.__operators__.add_41[0][0
#  _block_1 (Sequential)                                              ]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_42 (T  (None, 15, 15, 512)          0         ['convnext_base_downsampling_b
#  FOpLambda)                                                         lock_1[0][0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_42[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_43 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_42[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_43[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_44 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_43[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_44[0][0
#  k_3_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_45 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_44[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_45[0][0
#  k_4_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_46 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_45[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_46[0][0
#  k_5_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_47 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_46[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_47[0][0
#  k_6_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_48 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_47[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_48[0][0
#  k_7_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_49 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_48[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_49[0][0
#  k_8_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_50 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_49[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_50[0][0
#  k_9_depthwise_conv (Conv2D                                         ]']
#  )
# ...
#  k_25_identity (Activation)                                         25_layer_scale[0][0]']
#
#  tf.__operators__.add_67 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_66[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     25_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_67[0][0
#  k_26_depthwise_conv (Conv2                                         ]']
#  D)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_26_layernorm (LayerNorma                                         26_depthwise_conv[0][0]']
#  lization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_1 (Den                                         26_layernorm[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_26_gelu (Activation)                                             26_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_2 (Den                                         26_gelu[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_26_layer_scale (LayerSca                                         26_pointwise_conv_2[0][0]']
#  le)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_26_identity (Activation)                                         26_layer_scale[0][0]']
#
#  tf.__operators__.add_68 (T  (None, 15, 15, 512)          0         ['tf.__operators__.add_67[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     26_identity[0][0]']
#
#  convnext_base_downsampling  (None, 7, 7, 1024)           2099200   ['tf.__operators__.add_68[0][0
#  _block_2 (Sequential)                                              ]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_69 (T  (None, 7, 7, 1024)           0         ['convnext_base_downsampling_b
#  FOpLambda)                                                         lock_2[0][0]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['tf.__operators__.add_69[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_70 (T  (None, 7, 7, 1024)           0         ['tf.__operators__.add_69[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['tf.__operators__.add_70[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_71 (T  (None, 7, 7, 1024)           0         ['tf.__operators__.add_70[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  layer_normalization_1 (Lay  (None, 7, 7, 1024)           2048      ['tf.__operators__.add_71[0][0
#  erNormalization)                                                   ]']
#
#  batch_normalization_6 (Bat  (None, 7, 7, 1024)           4096      ['layer_normalization_1[0][0]'
#  chNormalization)                                                   ]
#
#  global_average_pooling2d_6  (None, 1024)                 0         ['batch_normalization_6[0][0]'
#   (GlobalAveragePooling2D)                                          ]
#
#  dense_24 (Dense)            (None, 1024)                 1049600   ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  dropout_18 (Dropout)        (None, 1024)                 0         ['dense_24[0][0]']
#
#  dense_25 (Dense)            (None, 612)                  627300    ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 612)                  0         ['dense_25[0][0]']
#
#  dense_26 (Dense)            (None, 210)                  128730    ['dropout_19[0][0]']
#
#  dropout_20 (Dropout)        (None, 210)                  0         ['dense_26[0][0]']
#
#  dense_27 (Dense)            (None, 5)                    1055      ['dropout_20[0][0]']
#
# ==================================================================================================
# Total params: 89377245 (340.95 MB)
# Trainable params: 89375197 (340.94 MB)
# Non-trainable params: 2048 (8.00 KB)
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss curves
plt.plot(model.history.history['loss'], label='Training loss')
plt.plot(model.history.history['val_loss'], label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy curves
plt.plot(model.history.history['accuracy'], label='Training accuracy')
plt.plot(model.history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np


val_results = model.evaluate(val_dataset)

y_true = []
y_pred = []

for x_val, y_val in val_dataset:
    predictions = model.predict(x_val)
    y_true.extend(np.argmax(y_val, axis=1))
    y_pred.extend(np.argmax(predictions, axis=1))

cm = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
#print(cm)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_true), yticklabels=np.unique(y_true))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# 68/68 [==============================] - 7s 104ms/step - loss: 0.8776 - accuracy: 0.8141
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 61ms/step
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       267
#            1       0.76      0.64      0.70       270
#            2       0.76      0.84      0.79       264
#            3       0.80      0.93      0.86       260
#            4       0.95      0.81      0.88       284
#
#     accuracy                           0.81      1345
#    macro avg       0.82      0.82      0.81      1345
# weighted avg       0.82      0.81      0.81      1345
