# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)

# %%
# Import libraries
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import tensorflow as tf
import tensorflow_addons as tfa

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, GlobalMaxPooling2D, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetB0, ResNet101
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix

# %%
# Calculate class_weights for 5 class

def get_class_weights(dataset, class_count=5):
    labels = []
    for _, label in dataset:
        labels.append(np.argmax(label.numpy(), 1)) # argmax needed if labels are in onehot enc.

    labels = np.hstack(labels) # list of np arrays stacking horizontally as a single np list
    samples_per_class = Counter(labels)  # Class index number mapping to number of samples in that class
    total_sample_count = len(labels) # total number of samples in this dataset


    class0_weight = (total_sample_count/ (class_count*samples_per_class[0]) )
    class1_weight = (total_sample_count/ (class_count*samples_per_class[1]) )
    class2_weight = (total_sample_count/ (class_count*samples_per_class[2]) )
    class3_weight = (total_sample_count/ (class_count*samples_per_class[3]) )
    class4_weight = (total_sample_count/ (class_count*samples_per_class[4]) )

    class_weights = {0: class0_weight, 1: class1_weight, 2: class2_weight, 3: class3_weight, 4: class4_weight}
    return class_weights

# %% [markdown]
#  ## Data Loading and Preprocessing

# %%
# Define dataset2 paths
data_dir = "/content/drive/MyDrive/SHSU-Projects/Final_files/Knee_Dataset_2_Augmented/train_augmented"


# Define batch size
batch_size = 20
IMAGE_SIZE = (240, 240)
classes = ['0Normal', '1Doubtful', '2Mild', '3Moderate', '4Severe']


train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='categorical',
    class_names=classes,  # Specify your class names
    shuffle=True,
    batch_size=batch_size,
    image_size=IMAGE_SIZE,
    validation_split=0.2,  # Adjust the validation split as needed
    subset='training',
    seed=1337
)



val_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='categorical',
    class_names=classes,
    shuffle=True,
    batch_size=batch_size,
    image_size=IMAGE_SIZE,
    validation_split=0.2,
    subset='validation',
    seed=1337
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/SHSU-Projects/Final_files/KneeOA_Dataset_2_Original/test',
    labels='inferred',
    label_mode='categorical',
    class_names=classes,
    shuffle=True,
    batch_size=batch_size,
    image_size=IMAGE_SIZE,
    #validation_split=0.2,
    #subset='test',
    seed=1337
)


class_index_to_label = {i: label for i, label in enumerate(train_dataset.class_names)}
print('Class index number mapping to class folder names: ',class_index_to_label)
class_weights_train = get_class_weights(train_dataset)
print('Class weights (train dataset): ', class_weights_train)

def preprocess_image(image, label):
    image = tfa.image.equalize(image)
    return image, label


train_dataset = train_dataset.map(preprocess_image).shuffle(buffer_size=200)
val_dataset = val_dataset.map(preprocess_image)


train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 6725 files belonging to 5 classes.
# Using 5380 files for training.
# Found 6725 files belonging to 5 classes.
# Using 1345 files for validation.
# Found 89 files belonging to 5 classes.
# Class index number mapping to class folder names:  {0: '0Normal', 1: '1Doubtful', 2: '2Mild', 3: '3Moderate', 4: '4Severe'}
# Class weights (train dataset):  {0: 0.992619926199262, 1: 0.9990714948932219, 2: 1.0018621973929236, 3: 1.0018621973929236, 4: 1.0046685340802988}

# %% [markdown]
# ## Learning Rate Scheduler

# %%
# Import libraries
import math
import sklearn
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

N_EPOCHS = 20
warm_up_ep  = 4
num_cycles  = 0.4
lr_max = 1e-4

def learning_rate_fn(current_step, num_warmup_steps, lr_max, num_cycles=0.50, num_training_steps=N_EPOCHS):
    if current_step < num_warmup_steps:
        # exponiancial warmup
        return lr_max * 2 ** -(num_warmup_steps - current_step)
    else:
        progress = float(current_step - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))
        return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr_max


def plot_lr_schedule(lr_schedule, epochs):
    fig = plt.figure(figsize=(20, 10))
    plt.plot([None] + lr_schedule + [None])
    x = np.arange(1, epochs + 1)
    x_axis_labels = [i if epochs <= 40 or i % 5 == 0 or i == 1 else None for i in range(1, epochs + 1)]
    plt.xlim([1, epochs])
    plt.xticks(x, x_axis_labels) # set tick step to 1 and let x axis start at 1

    plt.ylim([0, max(lr_schedule) * 1.1])

    schedule_info = f'start: {lr_schedule[0]:.1E}, max: {max(lr_schedule):.1E}, final: {lr_schedule[-1]:.1E}'
    plt.title(f'Step Learning Rate Schedule, {schedule_info}', size=18, pad=12)

    for x, val in enumerate(lr_schedule):
        if epochs <= 40 or x % 5 == 0 or x is epochs - 1:
            if x < len(lr_schedule) - 1:
                if lr_schedule[x - 1] < val:
                    ha = 'right'
                else:
                    ha = 'left'
            elif x == 0:
                ha = 'right'
            else:
                ha = 'left'
            plt.plot(x + 1, val, 'o', color='black');
            offset_y = (max(lr_schedule) - min(lr_schedule)) * 0.02
            plt.annotate(f'{val:.1E}', xy=(x + 1, val + offset_y), size=12, ha=ha)

    plt.xlabel('Epoch', size=16, labelpad=5)
    plt.ylabel('Learning Rate', size=16, labelpad=5)
    plt.grid()
    plt.show()




LR_SCHEDULE = [learning_rate_fn(step, num_warmup_steps=warm_up_ep, lr_max=lr_max, num_cycles=num_cycles, num_training_steps=N_EPOCHS) for step in range(N_EPOCHS)]
print('List of learning rate: ', LR_SCHEDULE)

plot_lr_schedule(LR_SCHEDULE, epochs=N_EPOCHS)
#lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=0)
# Out:
# List of learning rate:  [6.25e-06, 1.25e-05, 2.5e-05, 5e-05, 0.0001, 9.938441702975689e-05, 9.755282581475769e-05, 9.45503262094184e-05, 9.045084971874738e-05, 8.535533905932738e-05, 7.938926261462366e-05, 7.269952498697734e-05, 6.545084971874738e-05, 5.782172325201155e-05, 5e-05, 4.217827674798846e-05, 3.4549150281252636e-05, 2.7300475013022663e-05, 2.061073738537635e-05, 1.4644660940672627e-05]

# %%
from tensorflow.keras import backend as K

def weighted_ce(weights):
    weights = tf.keras.backend.variable(weights)

    def loss(y_true, y_pred):
        # Scale predictions so that the class probabilities of each sample sum to 1
        y_pred /= tf.keras.backend.sum(y_pred, axis=-1, keepdims=True)
        # Clip predictions to prevent NaNs and Inf values
        y_pred = tf.keras.backend.clip(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
        # Calculate the weighted categorical cross-entropy loss
        loss = y_true * tf.keras.backend.log(y_pred) * weights
        loss = -tf.keras.backend.sum(loss, -1)
        return loss
    return loss




def weighted_focal_loss(gamma=2.0, alpha=1.0, weights=None):
    def focal_loss(y_true, y_pred):
        # Clip predictions to avoid NaN loss values.
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)

        # Calculate cross-entropy term.
        cross_entropy = -y_true * K.log(y_pred)

        # Calculate focal term.
        focal_term = alpha * K.pow(1 - y_pred, gamma)

        # Weight focal term if custom weights are provided.
        if weights is not None:
            focal_term = focal_term * weights

        # Combine cross-entropy and focal terms.
        loss = cross_entropy * focal_term

        return K.mean(loss, axis=-1)
    return focal_loss

# %%
class_weights_list = list(class_weights_train.values())
class_weights_list
# Out:
# [0.992619926199262,
#  0.9990714948932219,
#  1.0018621973929236,
#  1.0018621973929236,
#  1.0046685340802988]

# %% [markdown]
# ## Callbacks

# %%
#lr_list = [ 0.00001, 0.00006, 0.00003, 0.00002, 0.00002, 0.00001, 0.00001, 0.00001, 0.00001, 0.00001, 0.00001 ]


my_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath='/content/drive/MyDrive/SHSU-Projects/Final_files/Dataset_2_after_augmentation_weightedFocalCE_convx.h5', save_best_only=True),
    #tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True),  # Stop training if no improvement after 7 epochs
    #tf.keras.callbacks.LearningRateScheduler(lambda step: lr_list[step], verbose=0),
    tf.keras.callbacks.LearningRateScheduler(lambda step: LR_SCHEDULE[step], verbose=0)
    #tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=3, min_lr=1e-5, verbose=1)
]

# %% [markdown]
# ## Model Definition and Compile

# %%
#base_model = tf.keras.applications.efficientnet.EfficientNetB0(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
#base_model = tf.keras.applications.resnet.ResNet101(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
base_model = tf.keras.applications.convnext.ConvNeXtBase(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
#base_model = tf.keras.applications.densenet.DenseNet121(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
#base_model = tf.keras.applications.vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

x = base_model.output
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(612, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
x = tf.keras.layers.Dense(210, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = tf.keras.layers.Dropout(0.5)(x)
predictions = tf.keras.layers.Dense(5, activation='softmax')(x)

for layer in base_model.layers:
    layer.trainable = True

model = tf.keras.Model(inputs=base_model.input, outputs=predictions)

# %%
model.compile(
    optimizer= tf.keras.optimizers.Adam(),
    loss=weighted_focal_loss(class_weights_list),
        metrics=['accuracy']
)


history = model.fit(
    train_dataset,
    epochs=N_EPOCHS,
    validation_data=val_dataset,
    callbacks=[my_callbacks],
)
# Out:
# Epoch 1/20
# 269/269 [==============================] - ETA: 0s - loss: 20.7462 - accuracy: 0.2322
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 168s 370ms/step - loss: 20.7462 - accuracy: 0.2322 - val_loss: 20.1473 - val_accuracy: 0.4528 - lr: 6.2500e-06
# Epoch 2/20
# 269/269 [==============================] - 103s 369ms/step - loss: 19.0262 - accuracy: 0.3976 - val_loss: 17.8694 - val_accuracy: 0.6416 - lr: 1.2500e-05
# Epoch 3/20
# 269/269 [==============================] - 106s 374ms/step - loss: 15.9053 - accuracy: 0.6279 - val_loss: 14.0188 - val_accuracy: 0.7621 - lr: 2.5000e-05
# Epoch 4/20
# 269/269 [==============================] - 108s 378ms/step - loss: 11.0856 - accuracy: 0.7545 - val_loss: 8.5092 - val_accuracy: 0.8424 - lr: 5.0000e-05
# Epoch 5/20
# 269/269 [==============================] - 106s 371ms/step - loss: 5.3330 - accuracy: 0.8351 - val_loss: 3.0539 - val_accuracy: 0.8104 - lr: 1.0000e-04
# Epoch 6/20
# 269/269 [==============================] - 104s 369ms/step - loss: 1.8812 - accuracy: 0.9240 - val_loss: 1.1123 - val_accuracy: 0.8208 - lr: 9.9384e-05
# Epoch 7/20
# 269/269 [==============================] - 109s 381ms/step - loss: 0.6670 - accuracy: 0.9721 - val_loss: 0.4179 - val_accuracy: 0.8796 - lr: 9.7553e-05
# Epoch 8/20
# 269/269 [==============================] - 106s 368ms/step - loss: 0.2616 - accuracy: 0.9742 - val_loss: 0.2190 - val_accuracy: 0.8558 - lr: 9.4550e-05
# Epoch 9/20
# 269/269 [==============================] - 104s 371ms/step - loss: 0.1229 - accuracy: 0.9823 - val_loss: 0.1447 - val_accuracy: 0.8558 - lr: 9.0451e-05
# Epoch 10/20
# 269/269 [==============================] - 104s 374ms/step - loss: 0.0763 - accuracy: 0.9799 - val_loss: 0.1118 - val_accuracy: 0.8654 - lr: 8.5355e-05
# Epoch 11/20
# 269/269 [==============================] - 107s 375ms/step - loss: 0.0544 - accuracy: 0.9870 - val_loss: 0.0929 - val_accuracy: 0.8736 - lr: 7.9389e-05
# Epoch 12/20
# 269/269 [==============================] - 106s 375ms/step - loss: 0.0449 - accuracy: 0.9918 - val_loss: 0.0700 - val_accuracy: 0.9338 - lr: 7.2700e-05
# Epoch 13/20
# 269/269 [==============================] - 92s 323ms/step - loss: 0.0393 - accuracy: 0.9942 - val_loss: 0.0833 - val_accuracy: 0.8937 - lr: 6.5451e-05
# Epoch 14/20
# 269/269 [==============================] - 90s 323ms/step - loss: 0.0367 - accuracy: 0.9955 - val_loss: 0.1008 - val_accuracy: 0.8699 - lr: 5.7822e-05
# Epoch 15/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.0360 - accuracy: 0.9935 - val_loss: 0.0771 - val_accuracy: 0.8959 - lr: 5.0000e-05
# Epoch 16/20
# 269/269 [==============================] - 104s 374ms/step - loss: 0.0341 - accuracy: 0.9963 - val_loss: 0.0689 - val_accuracy: 0.9160 - lr: 4.2178e-05
# Epoch 17/20
# 269/269 [==============================] - 104s 366ms/step - loss: 0.0320 - accuracy: 0.9993 - val_loss: 0.0600 - val_accuracy: 0.9346 - lr: 3.4549e-05
# Epoch 18/20
# 269/269 [==============================] - 104s 365ms/step - loss: 0.0315 - accuracy: 0.9991 - val_loss: 0.0566 - val_accuracy: 0.9450 - lr: 2.7300e-05
# Epoch 19/20
# 269/269 [==============================] - 91s 323ms/step - loss: 0.0309 - accuracy: 0.9993 - val_loss: 0.0592 - val_accuracy: 0.9353 - lr: 2.0611e-05
# Epoch 20/20
# 269/269 [==============================] - 102s 365ms/step - loss: 0.0304 - accuracy: 0.9996 - val_loss: 0.0562 - val_accuracy: 0.9442 - lr: 1.4645e-05

# %% [markdown]
# ## Layers counts

# %%
# Create a dictionary to store layer counts
layer_counts = {}

# Iterate through the model's layers
for layer in model.layers:
    layer_type = type(layer).__name__
    if layer_type in layer_counts:
        layer_counts[layer_type] += 1
    else:
        layer_counts[layer_type] = 1

# Print the total layer counts for each layer type
for layer_type, count in layer_counts.items():
    print(f"Layer type '{layer_type}' is applied {count} times.")
# Out:
# Layer type 'InputLayer' is applied 1 times.
# Layer type 'Normalization' is applied 1 times.
# Layer type 'Sequential' is applied 4 times.
# Layer type 'Conv2D' is applied 36 times.
# Layer type 'LayerNormalization' is applied 37 times.
# Layer type 'Dense' is applied 76 times.
# Layer type 'Activation' is applied 72 times.
# Layer type 'LayerScale' is applied 36 times.
# Layer type 'TFOpLambda' is applied 36 times.
# Layer type 'BatchNormalization' is applied 1 times.
# Layer type 'GlobalAveragePooling2D' is applied 1 times.
# Layer type 'Dropout' is applied 3 times.

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)

print('Test accuracy:', test_accuracy)
# Out:
# 5/5 [==============================] - 3s 787ms/step - loss: 0.1097 - accuracy: 0.8315
# Test accuracy: 0.8314606547355652

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_18 (InputLayer)       [(None, 240, 240, 3)]        0         []
#
#  convnext_base_prestem_norm  (None, 240, 240, 3)          0         ['input_18[0][0]']
#  alization (Normalization)
#
#  convnext_base_stem (Sequen  (None, 60, 60, 128)          6528      ['convnext_base_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          6400      ['convnext_base_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          256       ['convnext_base_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          66048     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          0         ['convnext_base_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          65664     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          128       ['convnext_base_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          0         ['convnext_base_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_144 (  (None, 60, 60, 128)          0         ['convnext_base_stem[0][0]',
#  TFOpLambda)                                                         'convnext_base_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          6400      ['tf.__operators__.add_144[0][
#  k_1_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          256       ['convnext_base_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          66048     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          0         ['convnext_base_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          65664     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          128       ['convnext_base_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          0         ['convnext_base_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_145 (  (None, 60, 60, 128)          0         ['tf.__operators__.add_144[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          6400      ['tf.__operators__.add_145[0][
#  k_2_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          256       ['convnext_base_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          66048     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 512)          0         ['convnext_base_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          65664     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          128       ['convnext_base_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 60, 60, 128)          0         ['convnext_base_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_146 (  (None, 60, 60, 128)          0         ['tf.__operators__.add_145[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 30, 30, 256)          131584    ['tf.__operators__.add_146[0][
#  _block_0 (Sequential)                                              0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          12800     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          512       ['convnext_base_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         263168    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         0         ['convnext_base_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          262400    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          256       ['convnext_base_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          0         ['convnext_base_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_147 (  (None, 30, 30, 256)          0         ['convnext_base_downsampling_b
#  TFOpLambda)                                                        lock_0[0][0]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          12800     ['tf.__operators__.add_147[0][
#  k_1_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          512       ['convnext_base_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         263168    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         0         ['convnext_base_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          262400    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          256       ['convnext_base_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          0         ['convnext_base_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_148 (  (None, 30, 30, 256)          0         ['tf.__operators__.add_147[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          12800     ['tf.__operators__.add_148[0][
#  k_2_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          512       ['convnext_base_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         263168    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 1024)         0         ['convnext_base_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          262400    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          256       ['convnext_base_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 30, 30, 256)          0         ['convnext_base_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_149 (  (None, 30, 30, 256)          0         ['tf.__operators__.add_148[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 15, 15, 512)          525312    ['tf.__operators__.add_149[0][
#  _block_1 (Sequential)                                              0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_150 (  (None, 15, 15, 512)          0         ['convnext_base_downsampling_b
#  TFOpLambda)                                                        lock_1[0][0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_150[0][
#  k_1_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_151 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_150[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_151[0][
#  k_2_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_152 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_151[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_152[0][
#  k_3_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_153 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_152[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_153[0][
#  k_4_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_154 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_153[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_154[0][
#  k_5_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_155 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_154[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_155[0][
#  k_6_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_156 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_155[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_156[0][
#  k_7_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_157 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_156[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_157[0][
#  k_8_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_158 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_157[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_158[0][
#  k_9_depthwise_conv (Conv2D                                         0]']
#  )
# ...
#  k_25_identity (Activation)                                         25_layer_scale[0][0]']
#
#  tf.__operators__.add_175 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_174[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     25_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          25600     ['tf.__operators__.add_175[0][
#  k_26_depthwise_conv (Conv2                                         0]']
#  D)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1024      ['convnext_base_stage_2_block_
#  k_26_layernorm (LayerNorma                                         26_depthwise_conv[0][0]']
#  lization)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         1050624   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_1 (Den                                         26_layernorm[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 2048)         0         ['convnext_base_stage_2_block_
#  k_26_gelu (Activation)                                             26_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          1049088   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_2 (Den                                         26_gelu[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          512       ['convnext_base_stage_2_block_
#  k_26_layer_scale (LayerSca                                         26_pointwise_conv_2[0][0]']
#  le)
#
#  convnext_base_stage_2_bloc  (None, 15, 15, 512)          0         ['convnext_base_stage_2_block_
#  k_26_identity (Activation)                                         26_layer_scale[0][0]']
#
#  tf.__operators__.add_176 (  (None, 15, 15, 512)          0         ['tf.__operators__.add_175[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     26_identity[0][0]']
#
#  convnext_base_downsampling  (None, 7, 7, 1024)           2099200   ['tf.__operators__.add_176[0][
#  _block_2 (Sequential)                                              0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_177 (  (None, 7, 7, 1024)           0         ['convnext_base_downsampling_b
#  TFOpLambda)                                                        lock_2[0][0]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['tf.__operators__.add_177[0][
#  k_1_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_178 (  (None, 7, 7, 1024)           0         ['tf.__operators__.add_177[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           51200     ['tf.__operators__.add_178[0][
#  k_2_depthwise_conv (Conv2D                                         0]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           2048      ['convnext_base_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 4096)           0         ['convnext_base_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           1024      ['convnext_base_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 7, 7, 1024)           0         ['convnext_base_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_179 (  (None, 7, 7, 1024)           0         ['tf.__operators__.add_178[0][
#  TFOpLambda)                                                        0]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  layer_normalization_4 (Lay  (None, 7, 7, 1024)           2048      ['tf.__operators__.add_179[0][
#  erNormalization)                                                   0]']
#
#  batch_normalization_17 (Ba  (None, 7, 7, 1024)           4096      ['layer_normalization_4[0][0]'
#  tchNormalization)                                                  ]
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_17[0][0]
#  7 (GlobalAveragePooling2D)                                         ']
#
#  dense_68 (Dense)            (None, 1024)                 1049600   ['global_average_pooling2d_17[
#                                                                     0][0]']
#
#  dropout_51 (Dropout)        (None, 1024)                 0         ['dense_68[0][0]']
#
#  dense_69 (Dense)            (None, 612)                  627300    ['dropout_51[0][0]']
#
#  dropout_52 (Dropout)        (None, 612)                  0         ['dense_69[0][0]']
#
#  dense_70 (Dense)            (None, 210)                  128730    ['dropout_52[0][0]']
#
#  dropout_53 (Dropout)        (None, 210)                  0         ['dense_70[0][0]']
#
#  dense_71 (Dense)            (None, 5)                    1055      ['dropout_53[0][0]']
#
# ==================================================================================================
# Total params: 89377245 (340.95 MB)
# Trainable params: 89375197 (340.94 MB)
# Non-trainable params: 2048 (8.00 KB)
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss curves
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy curves
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np


val_results = model.evaluate(test_dataset)

y_true = []
y_pred = []

for x_val, y_val in test_dataset:
    predictions = model.predict(x_val)
    y_true.extend(np.argmax(y_val, axis=1))
    y_pred.extend(np.argmax(predictions, axis=1))

cm = confusion_matrix(y_true, y_pred)

print("Confusion Matrix:")
#print(cm)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_true), yticklabels=np.unique(y_true))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# 5/5 [==============================] - 1s 95ms/step - loss: 0.1097 - accuracy: 0.8315
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 74ms/step
# Confusion Matrix:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84        18
#            1       0.60      0.71      0.65        17
#            2       0.93      0.72      0.81        18
#            3       1.00      0.94      0.97        18
#            4       0.89      0.89      0.89        18
#
#     accuracy                           0.83        89
#    macro avg       0.84      0.83      0.83        89
# weighted avg       0.85      0.83      0.83        89

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Nov 21 04:01:25 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    69W / 400W |  34151MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
